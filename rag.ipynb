# %%
import os
from dotenv import load_dotenv

load_dotenv()
PINECONE_API_KEY = os.getenv("PINECONE_API_KEY")
GOOGLE_API_KEY = os.getenv("GOOGLE_API_KEY")

# %% [markdown]
# ## Model

# %%
from langchain_google_genai import ChatGoogleGenerativeAI
from langchain_core.output_parsers import StrOutputParser

model = ChatGoogleGenerativeAI(google_api_key=GOOGLE_API_KEY, model="gemini-1.5-flash")
parser = StrOutputParser()
# Out:
# 'The Los Angeles Dodgers won the World Series in 2020, during the COVID-19 pandemic.'

# %% [markdown]
# Defining a prompt template:

# %%
from langchain.prompts import ChatPromptTemplate

prompt_template = '''
Answer the question based on the context below. Respond in a full sentence. If you can't answer the question reply "I don't know."

Context = {context}

Question = {question}
'''

prompt = ChatPromptTemplate.from_template(prompt_template)

# %%
chain = prompt | model | parser

# %%
# Testing the chain
chain.invoke({"context":"Mary's sister is Anna", "question":"Who is Mary's sister"})
# Out:
# "Mary's sister is Anna."

# %% [markdown]
# ## Getting the video transcript

# %% [markdown]
# We use Whisper to transcribe get the audio from the video url.

# %%
import whisper
from pytubefix import YouTube
import tempfile

video_url = "https://www.youtube.com/watch?v=SGSOCuByo24&ab_channel=LexFridman" # https://www.youtube.com/watch?v=cdiD-9MMpb0"
yt = YouTube(video_url)
audio_stream = yt.streams.filter(only_audio=True).first()


transcription_model = whisper.load_model("base")

filename = "audio.mp4"
audio_stream.download(filename=filename)

# %%
with open("transcription.txt", "w", encoding="utf-8") as f:
    transcription = transcription_model.transcribe(filename, fp16=False, verbose=True)["text"].strip()
    f.write(transcription)
    
os.remove(filename)

print("Transcription complete and audio file deleted.")
# Out:
# Detecting language using up to the first 30 seconds. Use `--language` to specify the language
# Detected language: English
# [00:00.000 --> 00:06.320]  The following is a conversation in Yalekun. He's considered to be one of the fathers of deep learning,
# [00:06.320 --> 00:11.520]  which, if you've been hiding under a rock, is the recent revolution in AI that's captivated
# [00:11.520 --> 00:17.440]  the world with the possibility of what machines can learn from data. He's a professor in New
# [00:17.440 --> 00:23.920]  York University, a vice president and chief AI scientist at Facebook, and co-recipient the Turing
# [00:23.920 --> 00:28.960]  Award for his work on deep learning. He's probably best known as the founding father of
# [00:28.960 --> 00:34.400]  convolutional neural networks. In particular, their application to optical character recognition
# [00:34.400 --> 00:41.760]  and the famed M-NIST data set. He is also an outspoken personality, unafraid to speak his mind in
# [00:41.760 --> 00:47.600]  a distinctive French accent and explore provocative ideas both in the rigorous medium of academic
# [00:47.600 --> 00:54.160]  research and the somewhat less rigorous medium of Twitter and Facebook. This is the Artificial
# [00:54.160 --> 00:59.520]  Intelligence Podcast. If you enjoy it, subscribe on YouTube, give it 5 stars and iTunes,
# [00:59.520 --> 01:06.240]  support it on Patreon, or simply connect with me on Twitter at Lex Friedman, spelled F-R-I-D-M-A-N.
# [01:06.800 --> 01:14.560]  And now here's my conversation with Yalekun. You said that 2001 space obviously is one of your favorite
# [01:14.560 --> 01:21.680]  movies. How 9000 decides to get rid of the astronauts for people that haven't seen the movie
# [01:21.760 --> 01:32.400]  spoiler alert because he believes that the astronauts will interfere with the mission. Do you see how
# [01:32.400 --> 01:39.760]  is flawed in some fundamental way or even evil or did he do the right thing? Neither. There's no
# [01:40.640 --> 01:47.040]  notion of evil in that context other than the fact that people die, but it was an example of what
# [01:47.040 --> 01:53.920]  people call value misalignment. You give an objective to a machine and the machine tries to
# [01:53.920 --> 01:59.120]  achieve this objective. And if you don't put any constraints on this objective, don't kill people
# [01:59.120 --> 02:06.960]  and don't do things like this. The machine, given the power, will do stupid things just to achieve
# [02:06.960 --> 02:11.920]  this objective or damaging things to achieve this objective. It's a little bit like we are used
# [02:12.400 --> 02:22.080]  in the context of human society. We put in place laws to prevent people from doing bad things
# [02:22.080 --> 02:26.000]  because spontaneously they would do those bad things. We have to shape their
# [02:27.760 --> 02:32.960]  cost function, their objective function if you want to laws to correct an education, obviously,
# [02:32.960 --> 02:40.800]  to correct for those. So maybe just pushing a little further on that point,
# [02:42.080 --> 02:49.120]  how there's a mission, there's fuzziness around the ambiguity around what the actual mission is.
# [02:52.000 --> 02:58.160]  Do you think that there will be a time from a utilitarian perspective where an AI system
# [02:58.160 --> 03:02.720]  where it is not misalignment, where it is alignment for the greater good of society,
# [03:02.720 --> 03:08.000]  that an AI system will make decisions that are difficult? Well, that's the trick. Eventually,
# [03:08.000 --> 03:13.040]  we'll have to figure out how to do this. Again, we're not starting from scratch because we've
# [03:13.040 --> 03:19.520]  been doing this with humans for millennia. So designing objective functions for people is something
# [03:19.520 --> 03:27.840]  that we know how to do and we don't do it by programming things, although the legal code is called
# [03:27.840 --> 03:33.360]  code. That tells you something. It's actually the design of an objective function. That's really
# [03:33.360 --> 03:38.160]  what legal code is. It tells you, here is what you can do, here is what you can't do. If you do it,
# [03:38.160 --> 03:44.560]  you pay that much. That's an objective function. So there is this idea somehow that it's a new thing
# [03:44.560 --> 03:48.400]  for people to try to design objective functions that are aligned with the common good, but no,
# [03:48.400 --> 03:55.040]  we've been writing laws from millennia and that's exactly what it is. So that's where the science
# [03:55.040 --> 04:02.000]  of lawmaking and computer science will come together. We'll come together.
# [04:02.800 --> 04:09.920]  So there's nothing special about how AI systems is just the continuation of tools used to make
# [04:09.920 --> 04:15.040]  some of these difficult ethical judgments that laws make. Yeah, and we have systems like this already
# [04:15.040 --> 04:22.560]  that make media decisions for ourselves in society that need to be designed in a way that they
# [04:22.560 --> 04:28.960]  like rules about things that sometimes have bad side effects and we have to be flexible enough
# [04:29.120 --> 04:32.720]  about those rules so that they can be broken when it's obvious that they shouldn't be applied.
# [04:34.000 --> 04:38.240]  So you don't see this on the camera here, but all the decoration in this room is all pictures from
# [04:38.240 --> 04:45.200]  2001 and space audices. Wow. Is that by accident or is there a lot? It's not by accident. It's by design.
# [04:47.520 --> 04:56.400]  Wow. So if you were to build how 10,000, so an improvement of how 9,000, what would you improve?
# [04:56.960 --> 05:02.960]  Well, first of all, I wouldn't ask it to hold secrets and tell lies because that's really what
# [05:02.960 --> 05:08.240]  breaks it in the end. That's the fact that it's asking itself questions about the purpose of the
# [05:08.240 --> 05:13.440]  mission and it's pieces things together that it's heard, all the secrets, the preparation of the
# [05:13.440 --> 05:18.960]  mission and the fact that it was discovery on the lunar surface that really was kept secret.
# [05:18.960 --> 05:24.880]  And one part of how's memory knows this and the other part is does not know it and is
# [05:24.880 --> 05:29.680]  supposed to not tell anyone and that creates the internal conflict. So you think there's never
# [05:29.680 --> 05:38.880]  should be a set of things that an AI system should not be allowed, like a set of facts that
# [05:38.880 --> 05:45.120]  should not be shared with the human operators. Well, I think no, I think that I think it should be a bit like
# [05:46.560 --> 05:54.080]  in the design of autonomous AI systems. There should be the equivalent of, you know,
# [05:55.040 --> 06:04.000]  the oath that he for quite, that doctor is signed up to. So there's certain things, certain rules
# [06:04.000 --> 06:09.840]  that you have to abide by and we can sort of hardwire this into our into our machines to kind of
# [06:09.840 --> 06:15.280]  make sure they don't go. So I'm not, you know, an advocate of the three laws over robotics,
# [06:15.280 --> 06:21.040]  you know, the azure of kind of thing because I don't think it's practical, but you know, some
# [06:21.120 --> 06:30.080]  level of limits. But to be clear, this is not, these are not questions that are kind of re-worth
# [06:31.200 --> 06:35.280]  asking today because we just don't have the technology to do this. We don't, we don't have a
# [06:35.280 --> 06:39.520]  ton of machine, we have intelligent machines, so my intelligent machines that are very specialized,
# [06:40.880 --> 06:45.520]  but they don't really sort of satisfy an objective, they're just, you know, kind of trained to do one
# [06:46.480 --> 06:53.280]  thing. So until we have some idea for design of a full-fledged autonomous intelligent system,
# [06:53.280 --> 06:57.920]  asking the question of how we design this objective, I think is a little too abstract.
# [06:58.480 --> 07:03.440]  It's a little too abstract, there's useful elements to it in that it helps us understand
# [07:04.240 --> 07:11.600]  our own ethical codes, humans. So even just as a thought experiment, if you imagine that
# [07:11.680 --> 07:17.760]  an AGI system is here today, how would we program it is a kind of nice thought experiment of
# [07:17.760 --> 07:25.280]  constructing how should we have a law, have a system of laws for our humans? It's just a nice
# [07:25.280 --> 07:32.240]  practical tool. And I think there's echoes of that idea too in the AI systems we have today that
# [07:32.240 --> 07:37.040]  don't have to be that intelligent. Yeah, like autonomous vehicles. These things stop creeping in
# [07:37.760 --> 07:41.520]  that they're worth thinking about, but certainly they shouldn't be framed as how.
# [07:42.560 --> 07:50.960]  Yeah, looking back, what is the most, I'm sorry if it's a silly question, but what is the most
# [07:50.960 --> 07:56.240]  beautiful or surprising idea and deep learning or AI in general that you've ever come across?
# [07:56.240 --> 08:03.840]  So personally, when you said back and just had this kind of, that's pretty cool moment,
# [08:03.840 --> 08:10.720]  that's nice. Well, I don't know if it's an idea rather than a sort of empirical fact,
# [08:12.160 --> 08:21.440]  the fact that you can build gigantic neural nets, train them on relatively small amounts of
# [08:21.440 --> 08:27.840]  data relatively with to castigrant and descent, and that actually works. Brakes everything you
# [08:27.840 --> 08:33.360]  read in every textbook, right? Every pre-deploning textbook that told you you need to have fewer
# [08:33.360 --> 08:39.280]  parameters than you have data samples. If you have a non-convex objective function, you have no
# [08:39.280 --> 08:42.960]  guarantee of convergence, all those things that you read in textbook and they tell you to stay away
# [08:42.960 --> 08:49.040]  from this and they're all wrong. There's a number of parameters, non-convex, and somehow, which is
# [08:49.040 --> 08:55.680]  very relative to the number of parameters data, it's able to learn anything. Right, does that still
# [08:55.680 --> 09:03.440]  surprise you today? Well, it was kind of obvious to me before I knew anything that this is a good
# [09:03.440 --> 09:07.760]  idea and then it became surprising that it worked because I started reading those textbooks.
# [09:09.280 --> 09:14.320]  Okay, so you talked to the intuition of why I was obvious to you if you remember?
# [09:14.320 --> 09:19.920]  Well, okay, so the intuition was it's sort of like, you know, those people in the late 19th century
# [09:20.000 --> 09:26.640]  who proved that heavier than air flight was impossible, right? And of course, you have birds,
# [09:26.640 --> 09:32.640]  right? They do fly. And so on the face of it, it's obviously wrong as an empirical question,
# [09:32.640 --> 09:38.480]  right? And so we have the same kind of thing that, you know, we know that the brain works.
# [09:38.480 --> 09:43.120]  We don't know how, but we know it works and we know it's a large network of neurons in interaction
# [09:43.120 --> 09:47.120]  and that learning takes place by changing the connection. So, kind of getting this level of
# [09:47.120 --> 09:52.160]  inspiration without covering the details, but sort of trying to derive basic principles.
# [09:54.640 --> 09:59.680]  You know, that kind of gives you a clue as to which direction to go. This is also the idea somehow
# [09:59.680 --> 10:06.320]  that I've been convinced of since I was an undergrad that even before that intelligence is inseparable
# [10:06.320 --> 10:13.440]  from learning. So the idea somehow that you can create an intelligent machine by basically programming
# [10:14.400 --> 10:20.080]  for me was an on-starter for, you know, from the start. Every intelligent entity that we know about
# [10:21.760 --> 10:26.400]  arrives at this intelligence through learning. So learning, you know, machine learning was
# [10:26.960 --> 10:31.440]  completely obvious path. Also because I'm lazy, so, you know,
# [10:33.360 --> 10:37.840]  it's automated basically everything and learning is the automation of intelligence.
# [10:38.400 --> 10:44.880]  Right. So, do you think, so what is learning then? What falls under learning because
# [10:45.600 --> 10:53.040]  do you think of reasoning as learning? Well, reasoning is certainly a consequence of
# [10:53.040 --> 10:58.880]  learning as well, just like other functions of the brain. The big question of reasoning is,
# [10:58.880 --> 11:04.560]  how do you make reasoning compatible with gradient-based learning? Do you think neural networks can
# [11:04.560 --> 11:09.360]  be made to reason? Yes, there is no question about that. Again, we have a good example, right?
# [11:11.040 --> 11:15.520]  The question is, is how? So the question is how much prior structure do you have to put into
# [11:15.520 --> 11:20.800]  the neural net so that something like human reasoning will emerge from it, you know, from learning?
# [11:21.680 --> 11:27.280]  Another question is all of our kind of model of what reasoning is that are based on logic
# [11:27.920 --> 11:34.320]  are discrete and are therefore incompatible with gradient-based learning. And I'm a very strong
# [11:34.320 --> 11:40.160]  believer in this idea of gradient-based learning. I don't believe that other types of learning that
# [11:40.160 --> 11:44.000]  don't use kind of gradient information if you want. So you don't like discrete mathematics,
# [11:44.000 --> 11:48.720]  you don't like anything discrete? Well, that's, it's not that I don't like it, it's just that it's
# [11:48.720 --> 11:53.760]  incompatible with learning and I'm a big fan of learning, right? So in fact, that's perhaps one
# [11:53.760 --> 11:59.200]  reason why deep learning has been kind of looked at with suspicion by a lot of computer scientists
# [11:59.200 --> 12:04.000]  because the math is very different. The math that you use for deep learning, you know, we're kind of,
# [12:04.000 --> 12:10.160]  as more to do with, you know, cybernetics, the kind of math you do in electrical engineering,
# [12:10.160 --> 12:15.600]  than the kind of math you do in computer science. And, you know, nothing in machine learning is
# [12:15.600 --> 12:21.280]  exact, right? Computer science is all about sort of, you know, obviously, compulsive attention to
# [12:21.280 --> 12:26.240]  details of like, you know, every index has to be right and you can prove that algorithm is correct,
# [12:27.120 --> 12:36.800]  machine learning is the science of solopiness really. That's beautiful. So, okay, maybe let's
# [12:36.800 --> 12:43.600]  feel around in the dark of what is a neural network that reasons or a system that
# [12:44.880 --> 12:53.440]  is works with continuous functions that's able to do build knowledge. However, we think about
# [12:53.440 --> 12:59.520]  reasoning. Build on previous knowledge, build on extra knowledge, create new knowledge,
# [12:59.520 --> 13:07.280]  generalize outside of any training set you ever built. What does that look like? If, yeah, maybe
# [13:07.280 --> 13:12.960]  give inklings of thoughts of what that might look like. Yeah, I mean, yes or no, if I had
# [13:12.960 --> 13:17.760]  precise ideas about this, I think, you know, we'll be building it right now. But, and there are
# [13:17.760 --> 13:22.480]  people working on this, though, who's main research interest is actually exactly that, right? So,
# [13:23.520 --> 13:29.360]  what you need to have is a working memory. So, you need to have some device, if you want,
# [13:29.920 --> 13:37.520]  some subsystem that can store a relatively large number of factual episodic information for,
# [13:38.480 --> 13:43.920]  you know, a reasonable amount of time. So, you know, in the in the brain, for example,
# [13:43.920 --> 13:52.320]  there are kind of three main types of memory. One is the sort of memory of the state of your cortex.
# [13:53.760 --> 13:57.600]  And that sort of disappears within 20 seconds. You can't remember things for more than about
# [13:57.600 --> 14:03.360]  20 seconds or a minute if you don't have any other form of memory. The second type of memory,
# [14:03.360 --> 14:07.600]  which is longer term, is just short term, is the hippocampus. So, you can, you know, you can
# [14:07.600 --> 14:15.120]  be to this building. You remember where the ex it is, where the elevators are. Some map of that
# [14:15.120 --> 14:20.240]  building that's stored in your hippocampus. You might remember something about what I said,
# [14:20.240 --> 14:24.320]  you know, a few minutes ago. I forgot it all already, for it's been erased, but, you know,
# [14:24.320 --> 14:30.640]  but that that would be in your hippocampus. And then the longer term memory is in the synapse,
# [14:30.640 --> 14:35.840]  the synapses, right? So, what you need if you want to system that skip people reasoning is that
# [14:35.840 --> 14:42.320]  you want the hippocampus like thing, right? And that's what people have tried to do with memory
# [14:42.320 --> 14:47.120]  networks and, you know, neural-turing machines and stuff like that, right? And now with transformers,
# [14:47.120 --> 14:52.560]  which have sort of a memory in there, kind of self-attention system, you can, you can take
# [14:52.560 --> 14:59.440]  of it this way. So, so that's one element you need. Another thing you need is some sort of
# [14:59.440 --> 15:08.400]  network that can access this memory, get an information back and then kind of crunch on it and then
# [15:09.120 --> 15:16.640]  do this iteratively multiple times because a chain of reasoning is, is a process by which you,
# [15:17.440 --> 15:22.320]  you can update your knowledge about the set of the world, but, you know, it's going to happen,
# [15:22.320 --> 15:28.160]  etc. And that has to be this sort of recurrent operation, basically. And you think that kind of,
# [15:29.120 --> 15:34.880]  if you think about a transformer, so that seems to be too small to contain the knowledge that's
# [15:36.160 --> 15:40.240]  to represent the knowledge that's contained Wikipedia, for example. But transformer doesn't have
# [15:40.240 --> 15:44.400]  this idea of recurrence. It's got a fixed number of layers and that's a number of steps that
# [15:44.400 --> 15:51.520]  it limits, basically, representation. But recurrence would build on the knowledge somehow. I mean,
# [15:51.520 --> 15:58.960]  it would evolve the knowledge and expand the amount of information, perhaps, or useful information
# [15:58.960 --> 16:05.360]  within that knowledge. But is this something they just can emerge with size? Because it seems like
# [16:05.360 --> 16:10.800]  everything we have now is just, no, it's not clear. It's not clear. I mean, how are you access and
# [16:10.800 --> 16:15.600]  writing to an associative memory inefficient way? I mean, so the original memory network maybe
# [16:15.600 --> 16:20.960]  had something like the right architecture, but if you try to scale up a memory network so that
# [16:20.960 --> 16:27.920]  the memory contains all the Wikipedia, it doesn't quite work. So there's a need for new ideas there.
# [16:27.920 --> 16:32.080]  Okay. But it's not the only form of reasoning. So there's another form of reasoning, which is through,
# [16:32.720 --> 16:40.000]  which is very classical also in some types of AI. And it's based on, let's call it energy
# [16:40.000 --> 16:48.320]  minimization. So you have some sort of objective, some energy function that represents the
# [16:49.920 --> 16:56.400]  quality or the negative quality. Energy goes up when things get bad and they get low when things
# [16:56.400 --> 17:06.080]  get good. So let's say you want to figure out what gestures do I need to do to grab an object or
# [17:06.080 --> 17:11.760]  work out the door. If you have a good model of your own body, a good model of the environment,
# [17:12.480 --> 17:17.200]  using this kind of energy minimization, you can make a, you can make, you can do planning. And it's
# [17:18.320 --> 17:23.680]  in optimal control, it's called model predictive control. You have a model of what's going to happen
# [17:23.680 --> 17:28.960]  in the world as consequence of your actions. And that allows you to buy energy minimization, figure out
# [17:28.960 --> 17:33.040]  the sequence of action that optimizes a particular objective function, which measures, you know,
# [17:33.040 --> 17:36.480]  minimizes a number of times, you're going to hit something and the energy you're going to spend
# [17:36.480 --> 17:43.520]  doing the gesture and et cetera. So that's a form of reasoning. Planning is a form of reasoning.
# [17:43.520 --> 17:52.640]  And perhaps what led to the ability of humans to reason is the fact that, or species that
# [17:52.640 --> 17:58.640]  appear before us had to do some sort of planning to be able to hunt and survive and survive the
# [17:58.640 --> 18:02.560]  winter in particular. And so, you know, it's the same capacity that you need to have.
# [18:03.280 --> 18:12.240]  So in your intuition is, if we look at expert systems and encoding knowledge as logic systems
# [18:13.520 --> 18:20.960]  as graphs, in this kind of way, is not a useful way to think about knowledge. Graphs are a little
# [18:20.960 --> 18:28.320]  brittle or logic representation. So basically, you know, variables that have values and then
# [18:28.320 --> 18:32.640]  constrained with doing them that are represented by rules is a little too rigid and too brittle.
# [18:32.640 --> 18:40.800]  So one of the, you know, some of the early efforts in that respect were to put probabilities on
# [18:40.800 --> 18:46.240]  them. So a rule, you know, if you have this in that symptom, you know, you have this disease
# [18:46.240 --> 18:50.480]  with that probability and you should prescribe that antibiotic with that probability, right?
# [18:50.560 --> 18:58.560]  That's the mycine system from the 70s. And that's what that branch of AI led to, you know,
# [18:58.560 --> 19:04.960]  busy networks and graphical models and causal inference and variational, you know, method.
# [19:04.960 --> 19:12.160]  So there is, I mean, certainly a lot of interesting work going on in this area. The main issue with
# [19:12.160 --> 19:19.440]  this is knowledge acquisition. How do you reduce a bunch of data to a graph of this type?
# [19:19.440 --> 19:26.320]  They are realizing the expert on the human being to encode, to add knowledge. And that's essentially
# [19:26.320 --> 19:32.400]  in practical. Yeah. So that's a big question. The second question is, do you want to represent
# [19:32.400 --> 19:38.240]  knowledge as symbols and do you want to manipulate them with logic? And again, that's incompatible
# [19:38.240 --> 19:45.520]  with learning. So one suggestion with Jeff Hinton has been advocating for many decades is
# [19:45.600 --> 19:53.360]  replace symbols by vectors. Think of it as pattern of activities in a bunch of neurons or units,
# [19:53.360 --> 20:00.640]  whatever you want to call them. And replace logic by continuous functions. Okay. And that becomes
# [20:00.640 --> 20:08.400]  now compatible. This is a very good set of ideas by written in a paper about 10 years ago by Leon
# [20:08.480 --> 20:15.440]  Boutou on who is here at Facebook. The title of the paper is for machine learning to machine
# [20:15.440 --> 20:21.680]  reasoning. And his idea is that a learning system should be able to manipulate objects that are
# [20:21.680 --> 20:26.560]  in a space and then put the result back in the same space. So it's this idea of working memory,
# [20:26.560 --> 20:35.680]  basically. And it's very enlightening. And in a sense, that might learn something like the simple
# [20:35.680 --> 20:42.480]  expert systems. I mean, it's with you can learn basic logic operations there. Yeah, quite
# [20:42.480 --> 20:47.600]  possibly. Yeah. This big debate on sort of how much prior structure you have to put in for this
# [20:47.600 --> 20:51.840]  kind of stuff to emerge. That's the debate I have with Gary Marcus and people like that. Yeah.
# [20:52.560 --> 20:59.120]  Yeah. So in the other person, so I just talked to GD Apparel, from the mention causal inference
# [20:59.120 --> 21:09.920]  world. So his worry is that the current neural networks are not able to learn what causes what
# [21:10.560 --> 21:15.920]  causal inference between things. So I think I think it's right and wrong about this. If he's
# [21:15.920 --> 21:23.760]  talking about the sort of classic type of neural nets, people didn't worry too much about this.
# [21:23.760 --> 21:27.280]  But there's a lot of people now working on causal inference. And there's a paper that just came out
# [21:27.280 --> 21:30.720]  last week by Leon Butou among others, the developers, by the way, and push for other people.
# [21:32.080 --> 21:38.800]  Exactly on that problem of how do you kind of get an neural net to sort of pay attention
# [21:39.440 --> 21:45.600]  to real causal relationships, which may also solve issues of bias in data,
# [21:46.560 --> 21:51.680]  can things like this. So I'd like to read that paper because that ultimately the challenge
# [21:51.680 --> 22:01.520]  here also seems to fall back on the human expert to ultimately decide causality between things.
# [22:01.520 --> 22:05.440]  I mean, people are not very good at establishing causality. First of all, so first of all,
# [22:05.440 --> 22:11.120]  you talk to physicists and physicists actually don't believe in causality because look at all the
# [22:11.120 --> 22:16.240]  basic laws of macro physics are time reversible. So there's no causality there of times.
# [22:16.240 --> 22:20.880]  Not right. Yeah. It's as soon as you start looking at macroscopic systems where there is
# [22:20.880 --> 22:26.640]  unpredictable randomness where there is clearly an hour of time, but it's a big mystery in physics
# [22:26.640 --> 22:33.840]  actually. Well, how that emerges. Is it emergent or is it part of the fundamental fabric of reality?
# [22:33.840 --> 22:39.200]  Yeah. Or is it bias of intelligent systems that because of the second law of thermodynamics,
# [22:39.200 --> 22:44.480]  we perceive a particular hour of time, but in fact, it's kind of arbitrary, right?
# [22:45.120 --> 22:50.320]  So yeah, physicists, mathematicians, they don't care about, I mean, the math doesn't care about
# [22:50.320 --> 22:55.120]  the flow of time. Well, certainly, certainly macro physics doesn't. People themselves are not
# [22:55.120 --> 23:01.680]  very good at establishing causal relationships. If you ask, I think it was in one of
# [23:01.680 --> 23:09.440]  similar papers book on children learning. He studied with Jean-Pierre Géin, he's the guy who
# [23:10.320 --> 23:14.080]  co-authored the book Perception with Marvin Minsky that kind of killed the first wave of neural nets.
# [23:14.560 --> 23:21.520]  But he was actually a learning person. He, in the sense of studying learning in humans and
# [23:21.520 --> 23:28.320]  machines, that's why he got interested in perceptron. And he wrote that if you ask a little kid
# [23:29.600 --> 23:35.920]  about what is the cause of the wind, a lot of kids will say, they will think for a while and
# [23:35.920 --> 23:40.080]  they will say, oh, it's the branches and the trees, they move and that creates wind, right?
# [23:40.080 --> 23:44.160]  So they get the causal relationship backwards. And it's because they are understanding of the
# [23:44.160 --> 23:47.680]  world and intuitive physics is not that great, right? I mean, these are like, you know, four or five
# [23:47.680 --> 23:54.480]  year old kids. You know, it gets better and then you understand that this can be, right? But there are
# [23:54.480 --> 24:02.080]  many things which we can, because of our common sense understanding of things, what people call
# [24:02.080 --> 24:08.320]  common sense, and we're understanding of physics, we can, there's a lot of stuff that we can figure
# [24:08.320 --> 24:15.040]  out causality, even with diseases, we can figure out what's not causing what often. There's a lot
# [24:15.040 --> 24:20.000]  of mystery, of course, but the idea is that you should be able to encode that into systems.
# [24:20.000 --> 24:22.720]  Because it seems unlikely to be able to figure that out themselves.
# [24:22.720 --> 24:27.360]  Well, whenever we can do intervention, but, you know, all of humanity has been completely diluted
# [24:27.360 --> 24:33.360]  for millennia, probably since existence, about a very, very wrong causal relationship,
# [24:33.440 --> 24:37.760]  where whatever you can explain your attributed to, you know, some deity, some divinity, right?
# [24:39.200 --> 24:42.720]  And that's a cup out. That's the way of saying, like, I don't know the cause, so, you know, God did
# [24:42.720 --> 24:52.880]  it, right? So you mentioned Marvin Ninsky and the irony of, you know, maybe causing the first
# [24:52.880 --> 24:59.120]  day I went to, you were there in the 90s, you were there in 80s, of course. In the 90s, what do you
# [24:59.120 --> 25:05.760]  think people lost faith in deep learning in the 90s and founded again a decade later over a decade
# [25:05.760 --> 25:12.320]  later? Yeah, it wasn't called deep learning yet. It was just called neural nets. Yeah, they lost
# [25:12.320 --> 25:18.080]  interest. I mean, I think I would put that around 1995, at least the machine learning community.
# [25:18.080 --> 25:25.120]  There was always a neural net community, but it became kind of disconnected from sort of mainstream
# [25:25.120 --> 25:31.840]  machine learning if you want. There were, it was basically actually a engineering that kept at it
# [25:33.120 --> 25:40.960]  and computer science, gave up on neural nets. I don't know, you know, I was too close to it to really
# [25:42.880 --> 25:50.720]  sort of analyze it with sort of a, and biased eye if you want, but I would make a few guesses.
# [25:50.800 --> 25:57.840]  So the first one is at the time, neural nets were, it was very hard to make them work.
# [25:57.840 --> 26:03.520]  In the sense that you would, you know, implement backprop in your favorite language,
# [26:04.960 --> 26:09.280]  and that very language was not Python, it was not MATLAB, it was not any of those things,
# [26:09.280 --> 26:14.560]  because they didn't exist, right? Yeah, to write it in Fort Rhino C or something like this, right?
# [26:15.280 --> 26:20.640]  So you would experiment with it. You would probably make some very basic mistakes,
# [26:21.360 --> 26:24.560]  like, you know, belly initialize your weights, make the network too small because you're
# [26:24.560 --> 26:28.080]  ready in the textbook, you know, you don't want too many parameters, right? And of course,
# [26:28.080 --> 26:31.120]  you know, and you would train on XOR because you didn't have any other data set to trade on.
# [26:31.920 --> 26:36.800]  And of course, you know, it works after time. So you'd say, give up. Also, you would train
# [26:36.800 --> 26:41.600]  you to batch gradient, which, you know, isn't sufficient. So there was a lot of, there was
# [26:41.600 --> 26:46.160]  bag of tricks that you had to know to make those things work or you had to reinvent.
# [26:46.880 --> 26:49.520]  And a lot of people just didn't and they just couldn't make it work.
# [26:51.200 --> 26:57.360]  So that's one thing. The investment in software platform to be able to kind of, you know,
# [26:57.360 --> 27:01.200]  display things, figure out why things don't work, kind of get a good intuition for how to get
# [27:01.200 --> 27:05.520]  them to work, have enough flexibility so you can create, you know, network architecture is a
# [27:05.520 --> 27:10.000]  lot of complexion on that and stuff like that. It was hard. I mean, you had to write everything
# [27:10.080 --> 27:12.880]  from scratch. And again, you didn't have any Python or MATLAB or anything, right?
# [27:13.920 --> 27:20.080]  So I read that, started to drop, but I read that you wrote in in LISP, the, the first versions of
# [27:20.800 --> 27:24.880]  Lynette with the convolution neural networks, which by the way, one of my favorite languages.
# [27:24.880 --> 27:30.000]  It's that's how I knew your legit, touring award, whatever this, with the program,
# [27:30.000 --> 27:34.960]  the LISP. That's still my favorite language. But it's not that we programmed in LISP,
# [27:35.040 --> 27:40.480]  is that we had to write all this interpreter. Okay. Because it's not like that's one that existed.
# [27:40.480 --> 27:46.400]  So we wrote a LISP interpreter that we hooked up to, you know, a backhand library that we wrote
# [27:46.400 --> 27:51.440]  also for sort of neural network computation. And then after a few years around 1991, we invented
# [27:51.440 --> 27:56.960]  this idea of basically having modules that know how to forward propagate and back propagate
# [27:56.960 --> 28:03.440]  gradients and then interconnecting those modules in a graph. Liumbe2 had made proposals on this
# [28:03.440 --> 28:07.360]  about this in the late 80s. And we were able to implement this using LISP system.
# [28:08.320 --> 28:10.320]  Eventually, we wanted to use that system to make
# [28:11.840 --> 28:15.440]  build production code for character recognition at Bell Labs. So we actually wrote a
# [28:15.440 --> 28:20.400]  compiler for that LISP interpreter so that Patricia Mard, who's not Microsoft, kind of did the
# [28:20.400 --> 28:26.640]  bulk of it with Leon and me. And so we could write our system in LISP and then compile to C,
# [28:26.640 --> 28:32.160]  and then we'll have a self-contained, complete system that could kind of do the entire thing.
# [28:33.440 --> 28:37.920]  Neither PyTorch nor TensorFlow can do this today. Yeah, okay. It's coming.
# [28:40.240 --> 28:44.880]  I mean, there's something like that in PyTorch called, you know, Torch script. And so,
# [28:45.680 --> 28:48.640]  you know, we had to write our LISP interpreter, we had to write our LISP compiler, we had to
# [28:48.640 --> 28:54.000]  invest a huge amount of effort to do this. And not everybody, if you don't completely believe in
# [28:54.000 --> 28:59.280]  a concept, you're not going to invest the time to do this. Now, at the time also, you know,
# [28:59.280 --> 29:04.480]  what today, this would turn into Torch or PyTorch or TensorFlow or whatever, we'd put it in
# [29:04.480 --> 29:11.360]  open source, everybody would use it and, you know, realize it's good. Back before 1995, working at AT&T,
# [29:11.360 --> 29:18.080]  there's no way the lawyers would let you release anything in open source of this nature. And so,
# [29:18.080 --> 29:23.120]  we could not distribute our code really. And at that point, and started going a million
# [29:23.120 --> 29:28.880]  tangents, but on that point, I also read that there was some almost pat, like a patent on
# [29:28.880 --> 29:36.480]  commercial neural networks. Yes, there was. So that, first of all, I mean, just who actually
# [29:38.080 --> 29:49.040]  that ran out, that thankfully 2007. 2007. What, can we just talk about that first? I know you're
# [29:49.040 --> 29:56.000]  a Facebook, but you also know why you and what does it mean to patent ideas like these
# [29:57.200 --> 30:04.560]  software ideas, essentially, or what are mathematical ideas? Or what are they? Okay, so they're not
# [30:04.560 --> 30:10.800]  mathematical ideas. So there are algorithms. And there was a period where the US patent
# [30:10.800 --> 30:17.760]  office would allow the patent of software as long as it was embodied. The Europeans are very
# [30:17.760 --> 30:23.440]  different. They don't quite accept that. They have a different concept, but, you know, I don't,
# [30:23.440 --> 30:28.000]  I don't, I mean, I never actually strongly believed in this, but I don't believe in this kind of
# [30:28.000 --> 30:37.360]  patent. Facebook basically doesn't believe in this kind of patent. Google, five patents because
# [30:37.360 --> 30:42.800]  they've been burned with Apple. And so now they do this for defensive purpose, but usually they say,
# [30:42.960 --> 30:47.920]  we're not going to see you if you're in French. Facebook has a similar policy, they say, you know,
# [30:47.920 --> 30:51.600]  we've had patent on certain things. For defensive purpose, we're not going to see you if you're
# [30:51.600 --> 30:59.680]  in French, when they see you through us. So the industry does not believe in patents. They are
# [30:59.680 --> 31:06.160]  there because of, you know, the legal landscape and various things, but I don't really believe in
# [31:06.160 --> 31:11.280]  patents for this kind of stuff. Okay, so that's that's a great thing. So I tell you a word story.
# [31:11.280 --> 31:17.040]  Yeah, so what happens was the first, the first patent about commercial net was about kind of the
# [31:17.040 --> 31:21.200]  early version of commercial net that didn't have separate pulling layers. It had, you know,
# [31:22.000 --> 31:26.720]  conventional layers with tried more than one if you want, right? And then there was a second one
# [31:26.720 --> 31:33.600]  on commercial nets with separate pulling layers, turning with backprop. And there were files
# [31:33.600 --> 31:39.120]  filed in 89 and 90, 90 years, something like this. At the time, the life of a patent was 17 years.
# [31:40.080 --> 31:43.760]  So here's what happened over the next few years is that we started developing
# [31:44.560 --> 31:50.720]  character recognition technology around commercial nets. And in 1994,
# [31:52.160 --> 31:58.240]  a check reading system was deployed in ATM machines. In 1995, it was for large
# [31:58.240 --> 32:01.600]  check reading machines in back offices, et cetera. And those systems were
# [32:03.360 --> 32:07.360]  developed by an engineering group that we were collaborating with at AT&T, and they were
# [32:07.360 --> 32:14.560]  commercialized by NCR, which at the time was a civil area of AT&T. Now AT&T split up in 1996,
# [32:16.160 --> 32:22.160]  1996. And the lawyer just looked at all the patents and distributed the patents among the various
# [32:22.160 --> 32:27.600]  companies. They gave the, you know, the commercial net patent to NCR because they were actually selling
# [32:27.600 --> 32:33.920]  products that used it. But nobody at NCR had any idea what the commercial net was. Yeah. Okay.
# [32:34.000 --> 32:41.440]  So between 1996 and 2007, there's a whole period until 2002 where I didn't actually work on
# [32:41.440 --> 32:47.520]  machine running or crunch on that I resumed working on this around 2002. And between 2002 and 2007,
# [32:47.520 --> 32:52.080]  I was working on them, crossing my finger that nobody at NCR would notice. And nobody noticed.
# [32:52.080 --> 32:59.840]  Yeah. And I hope that this kind of somewhat, as you said, lawyers aside relative openness
# [32:59.840 --> 33:06.160]  of the community now will continue. It accelerates the entire progress of the industry. And
# [33:07.760 --> 33:14.240]  you know, the problems that Facebook and Google and others are facing today is not whether
# [33:14.240 --> 33:19.280]  Facebook or Google or Microsoft or IBM or whoever is ahead of the other is that we don't have the
# [33:19.280 --> 33:23.280]  technology to build this things we want to build. We want to build intelligent virtual assistants that
# [33:23.280 --> 33:28.880]  have common sense. We don't have monopoly and good ideas for this. We don't believe we do. Maybe others
# [33:29.040 --> 33:35.280]  believe they do, but we don't. Okay. If a startup tells you they have the secret to, you know,
# [33:35.280 --> 33:40.160]  human-level intelligence and common sense, don't believe them. They don't. And it's going to take
# [33:40.160 --> 33:47.360]  the entire work of the world research community for a while to get to the point where you can go
# [33:47.360 --> 33:51.680]  often in each of those companies can start to build things on this. We're not there yet.
# [33:51.760 --> 33:59.280]  It's absolutely. And this calls to the gap between the space of ideas and the rigorous testing of
# [33:59.280 --> 34:05.520]  those ideas of practical application that you often speak to. You've written advice saying,
# [34:05.520 --> 34:10.480]  don't get fooled by people who claim to have a solution to artificial general intelligence,
# [34:10.480 --> 34:15.440]  who claim to have an AI system that works just like the human brain or who claim to have figured
# [34:15.600 --> 34:22.320]  out how the brain works. Ask them what the error rate they get on M-nist or image net.
# [34:23.280 --> 34:27.280]  This is a little dated, by the way. I mean, five years. Yes.
# [34:27.280 --> 34:31.920]  It's loose counting. Okay. But I think your opinion is to amnist an image net.
# [34:33.920 --> 34:38.960]  Yes, maybe dated. There may be new benchmarks, right? But I think that philosophy is when you
# [34:38.960 --> 34:45.840]  still in somewhat hold that benchmarks and the practical testing, the practical application is
# [34:45.840 --> 34:50.480]  where you really get to test the ideas. Well, it may not be completely practical. For example,
# [34:50.480 --> 34:56.720]  it could be a toy dataset, but it has to be some sort of task that the community as a whole
# [34:56.720 --> 35:01.440]  has accepted as some sort of standard kind of benchmark if you want. It doesn't need to be real.
# [35:01.440 --> 35:06.480]  So for example, many years ago here at Fair, people, you know, Chess and West,
# [35:06.480 --> 35:11.120]  on Antoine Bourne, and a few others proposed the Babbit tasks, which were kind of a toy problem
# [35:11.120 --> 35:16.960]  to test the ability of machines to reason actually to access working memory and things like this.
# [35:16.960 --> 35:22.400]  And it was very useful, even though it wasn't a real task. Amnist is kind of halfway a real task.
# [35:23.600 --> 35:29.680]  So, you know, toy problems can be very useful. It's just that I was reassured by the fact that
# [35:29.680 --> 35:33.840]  a lot of people, particularly a lot of people, we need to invest. We'd be fooled by people
# [35:33.840 --> 35:38.800]  telling them, oh, we have, you know, the algorithm of the cortex and you should give us 50 million.
# [35:39.360 --> 35:42.320]  Yes, absolutely. So there's a lot of people who
# [35:44.160 --> 35:50.000]  try to take advantage of the hype for business reasons and so on. But let me sort of talk to this
# [35:50.000 --> 35:57.600]  idea that new ideas, the ideas that push the field forward may not yet have a benchmark.
# [35:58.560 --> 36:02.480]  Or it may be very difficult to establish a benchmark. I agree. That's part of the process.
# [36:02.480 --> 36:06.480]  It's the machine benchmark. This part of the process. So what are your thoughts about?
# [36:07.200 --> 36:14.880]  So we have these benchmarks on around stuff we can do with images from classification to captioning
# [36:14.880 --> 36:19.840]  to just every kind of information you can pull out from images in the surface level. There's audio
# [36:19.840 --> 36:26.720]  data sets, there's some video. What can we start, natural language? What kind of stuff?
# [36:27.440 --> 36:33.360]  What kind of benchmarks do you see that start creeping on to more something like intelligence,
# [36:33.360 --> 36:39.920]  like reasoning, like maybe you don't like the term, but AGI, echoes of that kind of
# [36:40.480 --> 36:46.560]  realization. A lot of people are working on interactive environments in which you can train and test
# [36:47.200 --> 36:55.680]  intelligence systems. So there, for example, you know, it's the classical paradigm of super
# [36:55.680 --> 36:59.440]  vaginal things that you have a data set, you partition it into a training set,
# [36:59.440 --> 37:06.400]  validation set, test set, and there's a clear protocol. But why if the, that assumes that the samples
# [37:06.400 --> 37:11.360]  are statistically independent, you can exchange them, the order in which you see them doesn't
# [37:11.360 --> 37:16.160]  shouldn't matter, you know, things like that. But what if the answer you give determines the
# [37:16.160 --> 37:21.120]  next sample you see, which is the case, for example, in robotics, right? You robot does something
# [37:21.120 --> 37:25.920]  and then it gets exposed to a new room. And depending on where it goes, the room will be different.
# [37:25.920 --> 37:28.240]  So that's the, that creates the exploration problem.
# [37:30.080 --> 37:35.600]  The, what if the samples, so that creates also a dependency between samples, right? You, you,
# [37:36.960 --> 37:41.520]  if you move, if you can only move in space, the next sample you're going to see is going to be
# [37:41.520 --> 37:47.360]  probably in the same building, most likely. So, so the, so the, all the assumptions about the
# [37:47.360 --> 37:53.200]  validity of this training set, test set, hypothesis break. Whenever a machine can take an action that
# [37:53.200 --> 37:57.360]  has an influence in the, in the world, and it's what it's going to see. So people are sending up
# [37:57.360 --> 38:05.200]  artificial environments where, what that takes place, right? The robot runs around the 3D model
# [38:05.200 --> 38:10.320]  of a house and can interact with objects and things like this. So you do robotics by simulation,
# [38:10.320 --> 38:19.120]  you have those, you know, opening a gym type thing or mujoko kind of simulated robots and
# [38:19.120 --> 38:23.600]  you have games, you know, things like that. So that, that's where the field is going really,
# [38:23.600 --> 38:29.680]  this kind of environment. Now, back to the question of a GI, like, I don't like the term a GI,
# [38:31.200 --> 38:37.920]  because it implies that human intelligence is general and human intelligence is nothing like
# [38:37.920 --> 38:43.040]  general. It's very, very specialized. We think it's general. We like to think of ourselves as having
# [38:43.040 --> 38:47.600]  your own decisions. We don't. We're very specialized. We're only slightly more general. That's
# [38:47.600 --> 38:54.160]  why does it feel general? So you kind of the term general, I think what's impressive about humans
# [38:54.160 --> 39:01.280]  is ability to learn, as we were talking about learning, to learn in just so many different domains.
# [39:01.280 --> 39:07.200]  It's perhaps not arbitrarily general, but just you can learn in many domains and integrate that
# [39:07.200 --> 39:12.160]  knowledge somehow. Okay. The knowledge persists. So let me take a very specific example. Yes.
# [39:12.160 --> 39:17.840]  It's not an example. It's more like a quasi mathematical demonstration. So you have about one
# [39:17.840 --> 39:22.240]  million fibers coming out of one of your eyes, okay, two million total, but let's let's talk about
# [39:22.240 --> 39:28.240]  just one of them. It's one million nerve fibers, your optical nerve. Let's imagine that they are
# [39:28.240 --> 39:33.520]  binary, so they can be active or inactive, right? So the input to your visual cortex is one million
# [39:33.600 --> 39:42.400]  bits. Now they connect it to your brain in a particular way. And your brain has connections that
# [39:42.400 --> 39:46.720]  are kind of a little bit like a convolutional network, they're kind of local, you know, in space
# [39:46.720 --> 39:52.320]  and things like this. Now imagine I play a trick on you. It's a pretty nasty trick I admit.
# [39:52.960 --> 40:00.160]  I cut your optical nerve and I put a device that makes a run on perturbation of a permutation
# [40:00.240 --> 40:06.960]  of all the nerve fibers. So now what comes to your to your brain is a fixed but random permutation
# [40:06.960 --> 40:13.520]  of all the pixels. There's no way in hell that your visual cortex, even if I do this to you in
# [40:13.520 --> 40:20.880]  infancy, will actually learn vision to the same level of quality that you can. Got it. And you're
# [40:20.880 --> 40:25.600]  saying there's no way you've learned that. No, because now two pixels that are nearby in the world
# [40:25.600 --> 40:30.720]  well end up in very different places in your visual cortex. And your neurons there have no
# ...
# [01:03:23.520 --> 01:03:27.520]  obstacles they are after this. So the image I usually use is that there is a bunch of mountains
# [01:03:27.520 --> 01:03:31.280]  that we have to climb, and we can see the first one, but we don't know if there are 50 mountains
# [01:03:31.280 --> 01:03:38.880]  behind it or not. This might be a good metaphor for why AI researchers in the past have been overly
# [01:03:38.880 --> 01:03:48.480]  optimistic about the result of AI. For example, New Orleans Simon wrote the general problem solver,
# [01:03:49.440 --> 01:03:54.880]  and they called it the general problem solver. Of course, the first thing you realize is that all
# [01:03:54.880 --> 01:03:58.240]  the problems you want to solve are exponential. You can't actually use it for anything useful.
# [01:03:59.200 --> 01:04:04.560]  But you know, all you see is the first peak. So what are the first couple of peaks for her?
# [01:04:05.280 --> 01:04:10.480]  So the first peak, which is precisely what I'm working on, is self-supervised running. How do we
# [01:04:10.480 --> 01:04:15.600]  get machines to run models of the world by observation, kind of like babies and like young animals?
# [01:04:17.920 --> 01:04:24.240]  So we've been working with, you know, cognitive scientists. So this
# [01:04:24.320 --> 01:04:32.800]  Emendol DuPou, who's at Fair in Paris, is half time is also a researcher in French University, and
# [01:04:33.840 --> 01:04:41.920]  he has his chart that shows that which how many months of life baby humans can learn different
# [01:04:41.920 --> 01:04:50.560]  concepts, and you can measure this in various ways. So things like distinguishing
# [01:04:50.640 --> 01:04:54.880]  animate objects from inanimate, inanimate object, you can tell the difference at age two,
# [01:04:54.880 --> 01:05:01.760]  three months. Whether an object is going to stay stable is going to fall, you know, about four
# [01:05:01.760 --> 01:05:06.960]  months, you can tell. You know, there are four things like this, and then things like gravity,
# [01:05:06.960 --> 01:05:11.280]  the fact that objects are not supposed to float in the air, but are supposed to fall. You run this
# [01:05:11.280 --> 01:05:15.840]  around the age of eight or nine months. If you look at a lot of, you know, eight-month-old babies,
# [01:05:16.480 --> 01:05:20.240]  you give them a bunch of toys on their high chair. First thing they do is they throw them on the
# [01:05:20.240 --> 01:05:24.880]  ground and they look at them. It's because, you know, they're learning about actively learning
# [01:05:24.880 --> 01:05:32.080]  about gravity. So they're not trying to annoy you, but they, you know, they need to do the experiment,
# [01:05:32.080 --> 01:05:37.600]  right? So, you know, how do we get machines to learn like babies, mostly by observation with a
# [01:05:37.600 --> 01:05:42.800]  little bit of interaction, and learning those models of the world? Because I think that's really
# [01:05:42.800 --> 01:05:47.680]  a crucial piece of an intelligent autonomous system. So if you think about the architecture of an
# [01:05:47.680 --> 01:05:52.240]  intelligent autonomous system, it needs to have a predictive model of the world. So something that says,
# [01:05:52.880 --> 01:05:56.400]  here is a world at time t, here is a set of the world at time t plus one if I take this action.
# [01:05:57.440 --> 01:06:02.000]  And it's not a single answer. It can be, yeah, because of contributions. Yeah. Well,
# [01:06:02.000 --> 01:06:04.240]  but we don't know how to represent distributions in high-dimensional,
# [01:06:04.240 --> 01:06:08.880]  continuous spaces. So it's got to be something weaker than that, okay? But with some, some representation
# [01:06:09.040 --> 01:06:14.720]  of uncertainty. If you have that, then you can do what optimal control theory is called model
# [01:06:14.720 --> 01:06:19.520]  predictive control, which means that you can run your model with the hypothesis for sequence of
# [01:06:19.520 --> 01:06:24.720]  action and then see the result. Now, what you need, the other thing you need is some sort of objective
# [01:06:24.720 --> 01:06:30.000]  that you want to optimize. Am I reaching the goal of grabbing this object? Am I minimizing energy?
# [01:06:30.000 --> 01:06:35.440]  Am I whatever, right? So there is some sort of objective that you have to minimize. And so in
# [01:06:35.440 --> 01:06:39.280]  your head, if you had this model, you can figure out the sequence of action that will optimize your
# [01:06:39.280 --> 01:06:46.000]  objective. That objective is something that ultimately is rooted in your visual ganglia, at least in
# [01:06:46.000 --> 01:06:52.320]  the human brain. That's what it's about. Ganglia computes your level of contentment or miscontentment.
# [01:06:52.320 --> 01:06:57.520]  I don't know if that's a word. Unhappiness, okay? Yeah, this, yeah. This contentment. This
# [01:06:57.520 --> 01:07:04.880]  contentment, mate. And so your entire behavior is driven towards kind of minimizing that objective,
# [01:07:04.880 --> 01:07:12.480]  which is maximizing your contentment, computed by your visual ganglia. And what you have is an
# [01:07:12.480 --> 01:07:16.240]  objective function, which is basically a predictor of what your visual ganglia is going to tell you.
# [01:07:17.040 --> 01:07:21.600]  So you're not going to put your hand on fire because you know, it's going to, you know, it's going
# [01:07:21.600 --> 01:07:26.000]  to burn and you're going to get hurt. And you're predicting this because of your model of the world,
# [01:07:26.000 --> 01:07:32.720]  and your predictor of the subjective, right? So if you have those three components,
# [01:07:33.440 --> 01:07:39.120]  you have the four components. You have the hardwired contentment objective
# [01:07:41.200 --> 01:07:45.760]  computer, if you want, calculator. And then you have the three components. One is the
# [01:07:45.760 --> 01:07:51.600]  objective predictor, which basically predicts your level contentment. One is the model of the world.
# [01:07:52.400 --> 01:07:55.840]  And there's a third module that I didn't mention, which is the module that will
# [01:07:56.720 --> 01:08:01.120]  figure out the best course of action to optimize an objective given your model.
# [01:08:02.640 --> 01:08:03.680]  Okay? Yeah.
# [01:08:04.400 --> 01:08:12.240]  Cliffs of policy network, something like that, right? Now, you need those three components to
# [01:08:12.240 --> 01:08:16.400]  act autonomously intelligently. And you can be stupid in three different ways. You can be
# [01:08:16.400 --> 01:08:21.360]  stupid because your model of the world is wrong. You can be stupid because your objective
# [01:08:21.360 --> 01:08:28.800]  is not aligned with what you actually want to achieve. Okay? Inhumans that would be a psychopath.
# [01:08:30.000 --> 01:08:34.560]  And then the third thing you, the third way you can be stupid is that you have the right
# [01:08:34.560 --> 01:08:38.800]  model. You have the right objective. But you're unable to figure out a course of action
# [01:08:38.800 --> 01:08:45.920]  to optimize your objective given your model. Okay. Some people who are in charge of big countries
# [01:08:45.920 --> 01:08:52.640]  actually have all three that are wrong. All right. Which countries? I don't know. Okay. So
# [01:08:53.840 --> 01:08:58.320]  if we think about this, this agent, if you think about the movie, her, you've
# [01:08:59.760 --> 01:09:06.960]  criticized the art project that a Sophia the robot. And what that project essentially does
# [01:09:07.600 --> 01:09:14.080]  is uses our natural inclination to anthropomorphize things that look like human and give them more.
# [01:09:14.800 --> 01:09:18.720]  Do you think that could be used by AI systems like in the movie her?
# [01:09:21.200 --> 01:09:26.320]  So do you think that body is needed to create a feeling of intelligence?
# [01:09:27.200 --> 01:09:31.680]  Well, if Sophia was just an art piece, I would have no problem with it. But it's presented as
# [01:09:31.680 --> 01:09:38.480]  something else. Let me add in that comment real quick. If creators of Sophia could change something
# [01:09:38.480 --> 01:09:43.760]  about their marketing or behavior in general, what would it be? What's, I'm just about everything.
# [01:09:44.080 --> 01:09:53.120]  I mean, don't you think here's a tough question. Let me, so I agree with you. Sophia is not
# [01:09:53.920 --> 01:09:59.680]  the general public feels that Sophia can do way more than she actually can. That's right.
# [01:10:00.240 --> 01:10:08.960]  And the people who create a Sophia are not honestly, publicly communicating, trying to teach the
# [01:10:08.960 --> 01:10:21.280]  public. But here's a tough question. Don't you think the same thing is scientists in industry
# [01:10:21.280 --> 01:10:26.240]  and research are taking advantage of the same misunderstanding in the public when they create
# [01:10:26.240 --> 01:10:33.680]  AI companies or published stuff? Some companies, yes. I mean, there is no sense of there's no desire
# [01:10:33.680 --> 01:10:38.960]  to dilute. There's no desire to kind of over claim with something. It's not right. You
# [01:10:38.960 --> 01:10:42.400]  probably should be able to deny that, you know, has this result on the image net, you know, it's
# [01:10:42.400 --> 01:10:47.760]  pretty clear. I mean, it's not even interesting anymore. But, you know, I don't think there is that,
# [01:10:49.120 --> 01:10:56.640]  I mean, the reviewers are generally not very forgiving of, you know, unsupported claims of this type.
# [01:10:57.200 --> 01:11:02.720]  And, but there are certainly quite a few startups that have had a huge amount of hype around this,
# [01:11:02.720 --> 01:11:08.960]  that I find extremely damaging and I've been calling it out when I've seen it. So, yeah, but
# [01:11:08.960 --> 01:11:14.480]  to go back to your original question, like the necessity of embodiment, I think I don't think
# [01:11:14.480 --> 01:11:18.560]  embodiment is necessary. I think grounding is necessary. So I don't think we're going to get
# [01:11:18.560 --> 01:11:22.800]  machines that really understand language without some level of grounding in the world. And it's not
# [01:11:22.800 --> 01:11:27.920]  clear to me that language is a high enough bandwidth medium to communicate how the real world works.
# [01:11:27.920 --> 01:11:34.480]  I think for this, we start to ground out what grounding means. So, grounding means that so there is
# [01:11:34.480 --> 01:11:40.320]  this classic problem of common sense reasoning, you know, the, the Wiener grads Schema, right?
# [01:11:40.960 --> 01:11:46.560]  And so I tell you the trophy doesn't fit in the suitcase because the studio is too big, or the
# [01:11:46.560 --> 01:11:51.440]  trophy doesn't fit in the suitcase because it's too small. And the it in the first case refers to
# [01:11:51.440 --> 01:11:55.520]  the trophy in the second case to the suitcase. And the reason you can figure this out is because,
# [01:11:55.520 --> 01:11:59.120]  you know, the trophy in this case are, you know, one is supposed to fit in the other one and,
# [01:11:59.120 --> 01:12:03.520]  you know, the notion of size and the big object doesn't fit in a small object and this is the
# [01:12:03.520 --> 01:12:08.560]  tardis, you know, things like that, right? So you have this, this knowledge of other world works,
# [01:12:08.560 --> 01:12:14.880]  of geometry and things like that. I don't believe you can learn everything about the world, but just
# [01:12:14.880 --> 01:12:21.680]  being told in language how the world works. I think you need some low level perception of the world,
# [01:12:21.680 --> 01:12:26.560]  you know, be it visual touch, you know, whatever, but some higher bandwidth perception of the world.
# [01:12:26.560 --> 01:12:31.520]  So by reading all the world's text, you still may not have enough information. That's right.
# [01:12:32.400 --> 01:12:37.520]  There's a lot of things that just will never appear in text and that you can't really infer. So
# [01:12:37.520 --> 01:12:43.360]  I think common sense with the merge from, you know, certainly a lot of language interaction,
# [01:12:43.360 --> 01:12:49.520]  but also with watching videos or perhaps even interacting in virtual environments. And possibly,
# [01:12:50.080 --> 01:12:53.840]  you know, robot interacting in the real world, but I don't actually believe necessarily that
# [01:12:53.840 --> 01:12:58.160]  this last one is absolutely necessary, but I think there's a need for some grounding.
# [01:13:00.240 --> 01:13:04.800]  But the final product doesn't necessarily need to be embodied. No, you're saying.
# [01:13:04.800 --> 01:13:09.600]  No, it just needs to have an awareness of grounding. Right. But it needs to know how the world works
# [01:13:11.120 --> 01:13:14.240]  to have, you know, to not be frustrated, frustrating to talk to.
# [01:13:14.240 --> 01:13:21.280]  And you talked about emotions being important. That's the whole of the topic.
# [01:13:21.280 --> 01:13:26.720]  Well, so, you know, I talked about this, the visual ganglia, ganglia as the,
# [01:13:28.160 --> 01:13:34.000]  you know, the thing that calculates your level of mixed contentment contentment. And then there is this
# [01:13:34.000 --> 01:13:38.480]  other module that sort of tries to do a prediction of whether you're going to be content or not.
# [01:13:38.560 --> 01:13:45.040]  That's the source of some emotion. So fear, for example, is an anticipation of bad things that can
# [01:13:45.040 --> 01:13:50.240]  happen to you. Right. You have this inkling that there is some chance that something really bad is
# [01:13:50.240 --> 01:13:53.920]  going to happen to you and that creates fear. When you know for sure that something bad is going to
# [01:13:53.920 --> 01:13:58.720]  happen to you, you kind of give up. Right. It's not there anymore. It's uncertainty that creates fear.
# [01:13:59.440 --> 01:14:03.120]  So the punchline is, we're not going to have autonomous intelligence without emotions.
# [01:14:04.080 --> 01:14:04.880]  Okay.
# [01:14:07.040 --> 01:14:12.080]  Whatever the heck emotions are. So you mentioned very practical things of fear, but there's a lot of
# [01:14:12.080 --> 01:14:17.040]  other mess around it. But there are kind of the results of, you know, with drives. Yeah, there's
# [01:14:17.040 --> 01:14:23.360]  deeper biological stuff going on. And I've talked to a few folks on this. There's a fascinating stuff
# [01:14:23.360 --> 01:14:30.640]  that ultimately connects to our, to our brain. If we create an AGI system, sorry,
# [01:14:30.800 --> 01:14:36.160]  and human level intelligence, human level intelligence system. And you get to ask her one question,
# [01:14:37.040 --> 01:14:43.920]  what would that question be? You know, I think the first one will create, we'll probably not be
# [01:14:43.920 --> 01:14:49.200]  that smart. They'll be like a four year old. Okay. So you would have to ask her a question
# [01:14:49.920 --> 01:14:57.440]  to know she's not that smart. Yeah. Well, what's a good question to ask, you know, to be impressed?
# [01:14:57.440 --> 01:15:04.880]  Cause of wind. And if she answers, oh, it's because the leaves of the tree are moving and they
# [01:15:04.880 --> 01:15:12.480]  create wind. She's onto something. And she says, that's a stupid question. She's really onto
# [01:15:12.480 --> 01:15:18.400]  something. No. And then you tell her actually, you know, here is the real thing. And she says,
# [01:15:18.400 --> 01:15:25.200]  Oh, yeah, that makes sense. So questions that, that reveal the ability to do common sense
# [01:15:25.200 --> 01:15:28.880]  reasoning about the physical world. Yeah. And you know, some of them will call to any
# [01:15:28.880 --> 01:15:35.440]  friends, cause a reference. Well, it was a huge honor. Congratulations on the turning award.
# [01:15:35.440 --> 01:15:38.000]  Yeah. Thank you so much for talking today. Thank you. Appreciate it.
# Transcription complete and audio file deleted.

# %% [markdown]
# ## Splitting the transcript into chunks

# %%
from langchain_community.document_loaders import TextLoader

loader = TextLoader("transcription.txt")
text_documents = loader.load()
text_documents
# Out:
# [Document(metadata={'source': 'transcription.txt'}, page_content="The following is a conversation in Yalekun. He's considered to be one of the fathers of deep learning, which, if you've been hiding under a rock, is the recent revolution in AI that's captivated the world with the possibility of what machines can learn from data. He's a professor in New York University, a vice president and chief AI scientist at Facebook, and co-recipient the Turing Award for his work on deep learning. He's probably best known as the founding father of convolutional neural networks. In particular, their application to optical character recognition and the famed M-NIST data set. He is also an outspoken personality, unafraid to speak his mind in a distinctive French accent and explore provocative ideas both in the rigorous medium of academic research and the somewhat less rigorous medium of Twitter and Facebook. This is the Artificial Intelligence Podcast. If you enjoy it, subscribe on YouTube, give it 5 stars and iTunes, support it on Patreon, or simply connect with me on Twitter at Lex Friedman, spelled F-R-I-D-M-A-N. And now here's my conversation with Yalekun. You said that 2001 space obviously is one of your favorite movies. How 9000 decides to get rid of the astronauts for people that haven't seen the movie spoiler alert because he believes that the astronauts will interfere with the mission. Do you see how is flawed in some fundamental way or even evil or did he do the right thing? Neither. There's no notion of evil in that context other than the fact that people die, but it was an example of what people call value misalignment. You give an objective to a machine and the machine tries to achieve this objective. And if you don't put any constraints on this objective, don't kill people and don't do things like this. The machine, given the power, will do stupid things just to achieve this objective or damaging things to achieve this objective. It's a little bit like we are used in the context of human society. We put in place laws to prevent people from doing bad things because spontaneously they would do those bad things. We have to shape their cost function, their objective function if you want to laws to correct an education, obviously, to correct for those. So maybe just pushing a little further on that point, how there's a mission, there's fuzziness around the ambiguity around what the actual mission is. Do you think that there will be a time from a utilitarian perspective where an AI system where it is not misalignment, where it is alignment for the greater good of society, that an AI system will make decisions that are difficult? Well, that's the trick. Eventually, we'll have to figure out how to do this. Again, we're not starting from scratch because we've been doing this with humans for millennia. So designing objective functions for people is something that we know how to do and we don't do it by programming things, although the legal code is called code. That tells you something. It's actually the design of an objective function. That's really what legal code is. It tells you, here is what you can do, here is what you can't do. If you do it, you pay that much. That's an objective function. So there is this idea somehow that it's a new thing for people to try to design objective functions that are aligned with the common good, but no, we've been writing laws from millennia and that's exactly what it is. So that's where the science of lawmaking and computer science will come together. We'll come together. So there's nothing special about how AI systems is just the continuation of tools used to make some of these difficult ethical judgments that laws make. Yeah, and we have systems like this already that make media decisions for ourselves in society that need to be designed in a way that they like rules about things that sometimes have bad side effects and we have to be flexible enough about those rules so that they can be broken when  ...

# %%
from langchain_text_splitters import RecursiveCharacterTextSplitter

text_splitter = RecursiveCharacterTextSplitter(chunk_size=1500, chunk_overlap=20)
documents = text_splitter.split_documents(text_documents)

# %%
print(len(documents))
# Out:
# 48

# %% [markdown]
# ## Embedding and Vector Database

# %%
from langchain_google_genai.embeddings import GoogleGenerativeAIEmbeddings

embeddings = GoogleGenerativeAIEmbeddings(model="models/gemini-embedding-exp-03-07")

# %% [markdown]
# Manually create an index on [Pinecone](https://www.pinecone.io/) with dimension 3072 (to match the dimension of the embedding model we are using).

# %%
from pinecone import Pinecone

pc = Pinecone(api_key=PINECONE_API_KEY)

# Checking that the index exists
index = pc.Index("youtube-rag-2")
print(index.describe_index_stats())
# Out:
# {'dimension': 3072,
#  'index_fullness': 0.0,
#  'metric': 'cosine',
#  'namespaces': {'': {'vector_count': 48}},
#  'total_vector_count': 48,
#  'vector_type': 'dense'}

# %%
from langchain_pinecone import PineconeVectorStore

index="youtube-rag-2"
vectorstore = PineconeVectorStore.from_existing_index(index_name=index, embedding=embeddings)

# %% [markdown]
# We process a limited number of documents per minute to respect the rate limit of the free tier of the Google GenAI API. Specifically, we delay each request to avoid exceeding the allowed number of requests per minute.

# %%
import time 

MAX_REQUESTS_PER_MINUTE = 4
REQUEST_INTERVAL = 60  # 60 seconds
DELAY_BETWEEN_DOCS = REQUEST_INTERVAL / MAX_REQUESTS_PER_MINUTE  # 15 seconds delay between documents

for idx, doc in enumerate(documents):
    print(f"Embedding document {idx + 1} of {len(documents)}...")

    # Embed and add to Pinecone
    vectorstore.add_documents([doc])

    print(f"Processed document {idx + 1}/{len(documents)}.")

    # Delay to stay within 2 requests per minute
    if idx < len(documents) - 1:  # Avoid sleeping after the last document
        print(f"Waiting {DELAY_BETWEEN_DOCS} seconds before processing the next document...")
        time.sleep(DELAY_BETWEEN_DOCS)
# Out:
# Embedding document 1 of 48...
# Processed document 1/48.
# Waiting 15.0 seconds before processing the next document...
# Embedding document 2 of 48...
# Processed document 2/48.
# Waiting 15.0 seconds before processing the next document...
# Embedding document 3 of 48...
# Processed document 3/48.
# Waiting 15.0 seconds before processing the next document...
# Embedding document 4 of 48...
# Processed document 4/48.
# Waiting 15.0 seconds before processing the next document...
# Embedding document 5 of 48...
# Processed document 5/48.
# Waiting 15.0 seconds before processing the next document...
# Embedding document 6 of 48...
# Processed document 6/48.
# Waiting 15.0 seconds before processing the next document...
# Embedding document 7 of 48...
# Processed document 7/48.
# Waiting 15.0 seconds before processing the next document...
# Embedding document 8 of 48...
# Processed document 8/48.
# Waiting 15.0 seconds before processing the next document...
# Embedding document 9 of 48...
# Processed document 9/48.
# Waiting 15.0 seconds before processing the next document...
# Embedding document 10 of 48...
# Processed document 10/48.
# Waiting 15.0 seconds before processing the next document...
# Embedding document 11 of 48...
# Processed document 11/48.
# Waiting 15.0 seconds before processing the next document...
# Embedding document 12 of 48...
# Processed document 12/48.
# Waiting 15.0 seconds before processing the next document...
# Embedding document 13 of 48...
# Processed document 13/48.
# Waiting 15.0 seconds before processing the next document...
# Embedding document 14 of 48...
# Processed document 14/48.
# Waiting 15.0 seconds before processing the next document...
# Embedding document 15 of 48...
# Processed document 15/48.
# Waiting 15.0 seconds before processing the next document...
# Embedding document 16 of 48...
# Processed document 16/48.
# Waiting 15.0 seconds before processing the next document...
# Embedding document 17 of 48...
# Processed document 17/48.
# Waiting 15.0 seconds before processing the next document...
# Embedding document 18 of 48...
# Processed document 18/48.
# Waiting 15.0 seconds before processing the next document...
# Embedding document 19 of 48...
# Processed document 19/48.
# Waiting 15.0 seconds before processing the next document...
# Embedding document 20 of 48...
# Processed document 20/48.
# Waiting 15.0 seconds before processing the next document...
# Embedding document 21 of 48...
# Processed document 21/48.
# Waiting 15.0 seconds before processing the next document...
# Embedding document 22 of 48...
# Processed document 22/48.
# Waiting 15.0 seconds before processing the next document...
# Embedding document 23 of 48...
# Processed document 23/48.
# Waiting 15.0 seconds before processing the next document...
# Embedding document 24 of 48...
# Processed document 24/48.
# Waiting 15.0 seconds before processing the next document...
# Embedding document 25 of 48...
# Processed document 25/48.
# Waiting 15.0 seconds before processing the next document...
# Embedding document 26 of 48...
# Processed document 26/48.
# Waiting 15.0 seconds before processing the next document...
# Embedding document 27 of 48...
# Processed document 27/48.
# Waiting 15.0 seconds before processing the next document...
# Embedding document 28 of 48...
# Processed document 28/48.
# Waiting 15.0 seconds before processing the next document...
# Embedding document 29 of 48...
# Processed document 29/48.
# Waiting 15.0 seconds before processing the next document...
# Embedding document 30 of 48...
# Processed document 30/48.
# Waiting 15.0 seconds before processing the next document...
# Embedding document 31 of 48...
# Processed document 31/48.
# Waiting 15.0 seconds before processing the next document...
# Embedding document 32 of 48...
# Processed document 32/48.
# Waiting 15.0 seconds before processing the next document...
# Embedding document 33 of 48...
# Processed document 33/48.
# Waiting 15.0 seconds before processing the next document...
# Embedding document 34 of 48...
# Processed document 34/48.
# Waiting 15.0 seconds before processing the next document...
# Embedding document 35 of 48...
# Processed document 35/48.
# Waiting 15.0 seconds before processing the next document...
# Embedding document 36 of 48...
# Processed document 36/48.
# Waiting 15.0 seconds before processing the next document...
# Embedding document 37 of 48...
# Processed document 37/48.
# Waiting 15.0 seconds before processing the next document...
# Embedding document 38 of 48...
# Processed document 38/48.
# Waiting 15.0 seconds before processing the next document...
# Embedding document 39 of 48...
# Processed document 39/48.
# Waiting 15.0 seconds before processing the next document...
# Embedding document 40 of 48...
# Processed document 40/48.
# Waiting 15.0 seconds before processing the next document...
# Embedding document 41 of 48...
# Processed document 41/48.
# Waiting 15.0 seconds before processing the next document...
# Embedding document 42 of 48...
# Processed document 42/48.
# Waiting 15.0 seconds before processing the next document...
# Embedding document 43 of 48...
# Processed document 43/48.
# Waiting 15.0 seconds before processing the next document...
# Embedding document 44 of 48...
# Processed document 44/48.
# Waiting 15.0 seconds before processing the next document...
# Embedding document 45 of 48...
# Processed document 45/48.
# Waiting 15.0 seconds before processing the next document...
# Embedding document 46 of 48...
# Processed document 46/48.
# Waiting 15.0 seconds before processing the next document...
# Embedding document 47 of 48...
# Processed document 47/48.
# Waiting 15.0 seconds before processing the next document...
# Embedding document 48 of 48...
# Processed document 48/48.

# %%
vectorstore.similarity_search("What does Yann LeCun say about Model-based reinforcement learning?")[:3]
# Out:
# [Document(id='b3611c9e-0140-4228-9562-fbe32514d97f', metadata={'source': 'transcription.txt'}, page_content="idea of the effect of turning the wheel on the car and, you know, we know we need to stay on the road. So there's a lot of things that we bring to the table, which is basically our predictive model of the world. And that model allows us to not do stupid things and to basically stay within the context of things we need to do. We still face, you know, unpredictable situations and that's how we learn. But that allows us to learn really, really, really quickly. So that's called model-based reinforcement learning. There's some imitation and supervision because we have a driving instructor that tells us occasionally what to do. But most of the learning is learning the model, learning physics that we've done since we were babies. That's where almost all the learning physics is somewhat transferable from, it's transferable from syn descent. Stupid things are the same everywhere. Yeah. I mean, if you, you know, you have an experience of the world, you don't need to be particularly from a particular intelligence species to know that if you spill water from a container, you know, the rest is going to get wet. You might get wet. So, you know, cats know this, right? Yeah. So the main problem we need to solve is how do we learn models of the world? And that's what I'm interested in. That's what self-supervised learning is all about. If you were to try to construct a benchmark for, let's look at MNIST. I'd love that data set. But if you do think it's useful, interesting slash possible to"),
#  Document(id='b74b3d07-6e76-4c57-ad92-90cd2d3c3513', metadata={'source': 'transcription.txt'}, page_content="something that no human can do. I mean, I'm not sure what else to take away from that. Okay. Now, take those algorithms, the best hour algorithms we have today, to train a car to drive itself. It would probably have to drive millions of hours. It will have to kill thousands of pedestrians. It will have to run into thousands of trees. It will have to run off cliffs. And it had to run the cliff multiple times before it figures out that it's about idea, first of all, and second of all, before it figures out how not to do it. And so, I mean, this type of learning obviously does not reflect the kind of learning that animals and humans do. There is something missing that's really, really important there. And my hypothesis, which I've been advocating for like five years now, is that we have predictive models of the world that include the ability to predict under uncertainty. And what allows us to not run off a cliff when we learn to drive, most of us can learn to drive in about 20 or 30 hours of training without ever crashing, causing any accident. And if we drive next to a cliff, we know that if we turn the wheel to the right, the car is going to run off the cliff and nothing good is going to come out of this because we have a pretty good model of intuitive physics that tells us, you know, the car is going to fall. We know about gravity. Babies run this around the age of eight or nine months that objects don't float the fall. And, you know, we have a pretty good idea of the effect"),
#  Document(id='dc013fa8-87ac-4800-bc87-a3a7d68c35c3', metadata={'source': 'transcription.txt'}, page_content="sort of completely unsupervised, self-supervised learning, you ask the system for human help for selecting parts you want to annotate next. So if you think about a robot exploring a space or a baby exploring a space or a system exploring a dataset, every once in a while asking for human input, do you see value in that kind of work? I don't see transformative value. It's going to make things that we can already do more efficient or they will learn slightly more efficiently, but it's not going to make machines sort of significantly more intelligent. I think, and by the way, there is no opposition, there's no conflict between self-supervised learning reinforcement learning and super-vised learning or imitation learning or active learning. I see self-supervised learning as a preliminary to all of the above. Yes. So the example I use very often is how is it that, so if you use classical reinforcement learning, deeper reinforcement learning if you want. The best methods today so-called model-free reinforcement learning to learn to play Atari games, take about 80 hours of training to reach the level that any human can reach in about 15 minutes. They get better than humans, but it takes them a long time. Alpha Star, the Oreo Vini House and his teams, the system to play Starcraft plays a single map, a single type of player and can reach better than human level with about the equivalent of 200 years of training playing against itself. It's 200 years, right? It's not something that no")]

# %%
from langchain_core.runnables import RunnableParallel, RunnablePassthrough

retriever = vectorstore.as_retriever()

chain = (
    {"context": vectorstore.as_retriever(), "question": RunnablePassthrough()}
    | prompt | model | parser
)
response = chain.invoke("What does Yann LeCun say about Model-based reinforcement learning?")

# %%
response
# Out:
# 'Yann LeCun describes model-based reinforcement learning as incorporating a predictive model of the world that allows for quick learning by avoiding "stupid things," while still allowing for learning from unpredictable situations.'
